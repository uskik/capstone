# %% [markdown]
#  파이썬 기초

# %%
from pandas import Series, DataFrame
import pandas as pd
import numpy as np

# %%
obj = Series([4,7,-5,3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj.values
# Out:
# array([ 4,  7, -5,  3])

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj2 = Series([4,7,-5,3], index=['a','b','c','d'])
obj2
# Out:
# a    4
# b    7
# c   -5
# d    3
# dtype: int64

# %%
dd = DataFrame(np.arange(9.).reshape((3,3)), columns=list('abc'),
               index=['one','two','three'])
dd
# Out:
#          a    b    c
# one    0.0  1.0  2.0
# two    3.0  4.0  5.0
# three  6.0  7.0  8.0

# %%
c = ['b'in word for word in dd.columns ]
print(c)
# Out:
# [False, True, False]

# %%
dd.describe()
# Out:
#          a    b    c
# count  3.0  3.0  3.0
# mean   3.0  4.0  5.0
# std    3.0  3.0  3.0
# min    0.0  1.0  2.0
# 25%    1.5  2.5  3.5
# 50%    3.0  4.0  5.0
# 75%    4.5  5.5  6.5
# max    6.0  7.0  8.0

# %%
dd.min(axis=1)
# Out:
# one      0.0
# two      3.0
# three    6.0
# dtype: float64

# %%
# iloc 인덱스 loc 가 열 
# axis=0 열 axis=1 행
